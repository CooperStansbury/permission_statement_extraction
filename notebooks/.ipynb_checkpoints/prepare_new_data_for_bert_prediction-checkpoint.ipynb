# %% [markdown]
# ## Introduction
# The goal of this notebook is to ingest all textual content from the `data/raw/all_forms/` dir and re-format sentences so that bert can make predictions on them.

# %%
from platform import python_version
print("VERSION: ", python_version()) # expect 3.7.0
# Out:
# VERSION:  3.7.0

# %%
# fundementals 
import os
import re
import pandas as pd
import numpy as np

# zoomies
import dask.dataframe as dd
from dask.multiprocessing import get
from multiprocessing import cpu_count

# custom data loading functions
import load_data
import clean_data

# %%
# dirty spaCy error workaround:
get_ipython().config.get('IPKernelApp', {})['parent_appname'] = ""

# %%
# Data location
forms_dir = '../data/raw/all_forms'
raw_df = load_data.getDIRData(forms_dir)
raw_df.head()
# Out:
#    id                                       name  \
# 0   1           TAMU - HRPP Informed consent.txt
# 1   2  Potomac Primary Care_flu-consent-form.txt
# 2   3         OSU_Scheduled_Delivery_Consent.txt
# 3   4         consent_biorepository_12-19-14.txt
# 4   5         Cambridge_Consent_endodontics2.txt
#
#                                                 path  \
# 0  ../data/raw/all_forms/TAMU - HRPP Informed con...
# 1  ../data/raw/all_forms/Potomac Primary Care_flu...
# 2  ../data/raw/all_forms/OSU_Scheduled_Delivery_C...
# 3  ../data/raw/all_forms/consent_biorepository_12...
# 4  ../data/raw/all_forms/Cambridge_Consent_endodo...
#
#                                              rawText
# 0  ﻿NOT INTENDED FOR USE WITHOUT TAMU/BCD IRB APP...
# 1  PATIENT CONSENT FORM FOR SEASONAL INFLUENZA VA...
# 2  SCHEDULED DELIVERY:           Today’s Date: Da...
# 3  ﻿ Informed Consent Form and HIPAA Authorizatio...
# 4  INFORMAT IONAL USE ONLY  CONSENT FOR ENDODONTI...

# %% [markdown]
# ### Faster Processing into spaCy docs
# Here we use dask so that we can do things a little faster...

# %%
# just so we can mess it up and not feel bad....
df = raw_df

# %%
nCores = cpu_count()
print(nCores) # just 4 for my machine
# Out:
# 4

# %%
from_field = 'rawText'
copy_to = 'minimalCleaning'

df[copy_to] = dd.from_pandas(df,npartitions=nCores).\
   map_partitions(
      lambda df : df.apply(
         lambda x : clean_data.minimalTextCleaning(x,from_field),axis=1)).\
   compute(scheduler='threads')

df.head()
# Out:
#    id                                       name  \
# 0   1           TAMU - HRPP Informed consent.txt
# 1   2  Potomac Primary Care_flu-consent-form.txt
# 2   3         OSU_Scheduled_Delivery_Consent.txt
# 3   4         consent_biorepository_12-19-14.txt
# 4   5         Cambridge_Consent_endodontics2.txt
#
#                                                 path  \
# 0  ../data/raw/all_forms/TAMU - HRPP Informed con...
# 1  ../data/raw/all_forms/Potomac Primary Care_flu...
# 2  ../data/raw/all_forms/OSU_Scheduled_Delivery_C...
# 3  ../data/raw/all_forms/consent_biorepository_12...
# 4  ../data/raw/all_forms/Cambridge_Consent_endodo...
#
#                                              rawText  \
# 0  ﻿NOT INTENDED FOR USE WITHOUT TAMU/BCD IRB APP...
# 1  PATIENT CONSENT FORM FOR SEASONAL INFLUENZA VA...
# 2  SCHEDULED DELIVERY:           Today’s Date: Da...
# 3  ﻿ Informed Consent Form and HIPAA Authorizatio...
# 4  INFORMAT IONAL USE ONLY  CONSENT FOR ENDODONTI...
#
#                                      minimalCleaning
# 0  not intended for use without tamu/bcd irb appr...
# 1  patient consent form for seasonal influenza va...
# 2  scheduled delivery: today s date: date of sche...
# 3  informed consent form and hipaa authorization ...
# 4  informat ional use only consent for endodontic...

# %% [markdown]
# Note: this was not possible on the entire corpus the otherway (in hueristic extraction). We limited the conversions to samples only, so even though this is an expensive function, it's possible to manage on a single machine.

# %%
# %%time

convertFrom = 'minimalCleaning'
convertTo = 'DOC'

df[convertTo] = dd.from_pandas(df,npartitions=nCores).\
   map_partitions(
      lambda df : df.apply(
         lambda x :clean_data.getDocObjects(x, convertFrom),axis=1)).\
   compute(scheduler='threads')

df.head()
# Out:
# CPU times: user 6min 34s, sys: 2min 9s, total: 8min 44s
# Wall time: 3min 26s

# %%
df.head()
# Out:
#    id                                       name  \
# 0   1           TAMU - HRPP Informed consent.txt
# 1   2  Potomac Primary Care_flu-consent-form.txt
# 2   3         OSU_Scheduled_Delivery_Consent.txt
# 3   4         consent_biorepository_12-19-14.txt
# 4   5         Cambridge_Consent_endodontics2.txt
#
#                                                 path  \
# 0  ../data/raw/all_forms/TAMU - HRPP Informed con...
# 1  ../data/raw/all_forms/Potomac Primary Care_flu...
# 2  ../data/raw/all_forms/OSU_Scheduled_Delivery_C...
# 3  ../data/raw/all_forms/consent_biorepository_12...
# 4  ../data/raw/all_forms/Cambridge_Consent_endodo...
#
#                                              rawText  \
# 0  ﻿NOT INTENDED FOR USE WITHOUT TAMU/BCD IRB APP...
# 1  PATIENT CONSENT FORM FOR SEASONAL INFLUENZA VA...
# 2  SCHEDULED DELIVERY:           Today’s Date: Da...
# 3  ﻿ Informed Consent Form and HIPAA Authorizatio...
# 4  INFORMAT IONAL USE ONLY  CONSENT FOR ENDODONTI...
#
#                                      minimalCleaning  \
# 0  not intended for use without tamu/bcd irb appr...
# 1  patient consent form for seasonal influenza va...
# 2  scheduled delivery: today s date: date of sche...
# 3  informed consent form and hipaa authorization ...
# 4  informat ional use only consent for endodontic...
#
#                                                  DOC
# 0  (not, intended, for, use, without, tamu, /, bc...
# 1  (patient, consent, form, for, seasonal, influe...
# 2  (scheduled, delivery, :, today, s, date, :, da...
# 3  (informed, consent, form, and, hipaa, authoriz...
# 4  (informat, ional, use, only, consent, for, end...

# %%
# won't bother dasking this guy
getFrom = 'DOC'
convertTo = 'sentenceList'

df[convertTo] = df.apply(lambda row:clean_data.getSentenceList(row, getFrom),axis=1)

# %%
df.head()
# Out:
#    id                                       name  \
# 0   1           TAMU - HRPP Informed consent.txt
# 1   2  Potomac Primary Care_flu-consent-form.txt
# 2   3         OSU_Scheduled_Delivery_Consent.txt
# 3   4         consent_biorepository_12-19-14.txt
# 4   5         Cambridge_Consent_endodontics2.txt
#
#                                                 path  \
# 0  ../data/raw/all_forms/TAMU - HRPP Informed con...
# 1  ../data/raw/all_forms/Potomac Primary Care_flu...
# 2  ../data/raw/all_forms/OSU_Scheduled_Delivery_C...
# 3  ../data/raw/all_forms/consent_biorepository_12...
# 4  ../data/raw/all_forms/Cambridge_Consent_endodo...
#
#                                              rawText  \
# 0  ﻿NOT INTENDED FOR USE WITHOUT TAMU/BCD IRB APP...
# 1  PATIENT CONSENT FORM FOR SEASONAL INFLUENZA VA...
# 2  SCHEDULED DELIVERY:           Today’s Date: Da...
# 3  ﻿ Informed Consent Form and HIPAA Authorizatio...
# 4  INFORMAT IONAL USE ONLY  CONSENT FOR ENDODONTI...
#
#                                      minimalCleaning  \
# 0  not intended for use without tamu/bcd irb appr...
# 1  patient consent form for seasonal influenza va...
# 2  scheduled delivery: today s date: date of sche...
# 3  informed consent form and hipaa authorization ...
# 4  informat ional use only consent for endodontic...
#
#                                                  DOC  \
# 0  (not, intended, for, use, without, tamu, /, bc...
# 1  (patient, consent, form, for, seasonal, influe...
# 2  (scheduled, delivery, :, today, s, date, :, da...
# 3  (informed, consent, form, and, hipaa, authoriz...
# 4  (informat, ional, use, only, consent, for, end...
#
#                                         sentenceList
# 0  [(not, intended, for, use, without, tamu, /, b...
# 1  [(patient, consent, form, for, seasonal, influ...
# 2  [(scheduled, delivery, :, today, s, date, :, d...
# 3  [(informed, consent, form, and, hipaa, authori...
# 4  [(informat, ional, use, only, consent, for, en...

# %%
getFrom = 'sentenceList'
convertTo = 'cleanedSents'

def cleanSentenceList(row, field):
    """  clean sentence list, prepare for export to bert """
    
    cleaned_sents = []
    
    for sentence in row[field]:
        str_sent = sentence.text
        clean_text = re.sub('[^A-Za-z0-9]+', ' ', str_sent).strip()
        cleaned_sents.append(clean_text)

    return cleaned_sents

df[convertTo] = df.apply(lambda row:cleanSentenceList(row, getFrom),axis=1)

# %%
df.head()
# Out:
#    id                                       name  \
# 0   1           TAMU - HRPP Informed consent.txt
# 1   2  Potomac Primary Care_flu-consent-form.txt
# 2   3         OSU_Scheduled_Delivery_Consent.txt
# 3   4         consent_biorepository_12-19-14.txt
# 4   5         Cambridge_Consent_endodontics2.txt
#
#                                                 path  \
# 0  ../data/raw/all_forms/TAMU - HRPP Informed con...
# 1  ../data/raw/all_forms/Potomac Primary Care_flu...
# 2  ../data/raw/all_forms/OSU_Scheduled_Delivery_C...
# 3  ../data/raw/all_forms/consent_biorepository_12...
# 4  ../data/raw/all_forms/Cambridge_Consent_endodo...
#
#                                              rawText  \
# 0  ﻿NOT INTENDED FOR USE WITHOUT TAMU/BCD IRB APP...
# 1  PATIENT CONSENT FORM FOR SEASONAL INFLUENZA VA...
# 2  SCHEDULED DELIVERY:           Today’s Date: Da...
# 3  ﻿ Informed Consent Form and HIPAA Authorizatio...
# 4  INFORMAT IONAL USE ONLY  CONSENT FOR ENDODONTI...
#
#                                      minimalCleaning  \
# 0  not intended for use without tamu/bcd irb appr...
# 1  patient consent form for seasonal influenza va...
# 2  scheduled delivery: today s date: date of sche...
# 3  informed consent form and hipaa authorization ...
# 4  informat ional use only consent for endodontic...
#
#                                                  DOC  \
# 0  (not, intended, for, use, without, tamu, /, bc...
# 1  (patient, consent, form, for, seasonal, influe...
# 2  (scheduled, delivery, :, today, s, date, :, da...
# 3  (informed, consent, form, and, hipaa, authoriz...
# 4  (informat, ional, use, only, consent, for, end...
#
#                                         sentenceList  \
# 0  [(not, intended, for, use, without, tamu, /, b...
# 1  [(patient, consent, form, for, seasonal, influ...
# 2  [(scheduled, delivery, :, today, s, date, :, d...
# 3  [(informed, consent, form, and, hipaa, authori...
# 4  [(informat, ional, use, only, consent, for, en...
#
#                                         cleanedSents
# 0  [not intended for use without tamu bcd irb app...
# 1  [patient consent form for seasonal influenza v...
# 2  [scheduled delivery today s date date of sched...
# 3  [informed consent form and hipaa authorization...
# 4  [informat ional use only consent for endodonti...

# %%
new_rows = []

for index, row in df.iterrows():
    
    for sent in row['cleanedSents']:
    
        trls_row = {
            'id':row['id'],
            'sentence':sent   
            }
        
        new_rows.append(trls_row)
        
output_df = pd.DataFrame(new_rows)
output_df.head()
# Out:
#    id                                           sentence
# 0   1  not intended for use without tamu bcd irb appr...
# 1   1                                      project title
# 2   1  you are invited to take part in a research stu...
# 3   1  the information in this form is provided to he...
# 4   1  if you decide to take part in the study you wi...

# %% [markdown]
# ## Remove old files
# caution advised

# %%
os.remove('../data/raw_bert_inputs/new_data.tsv')

# %% [markdown]
# ### Output for Bert

# %%
output_df.to_csv('../data/raw_bert_inputs/new_data.tsv', sep='\t', index=False, header=True)
