# %% [markdown]
# # Introduction
#
# Two subgroups of code:
# 1. Featuere Extraction from the Annotations (Data Turk)
# 1. Train classifiers based on Featuere Extraction.

# %%
from platform import python_version
print("VERSION: ", python_version()) # expect 3.7.0
# Out:
# VERSION:  3.7.0

# %%
import pandas as pd
import numpy as np
import json
import string
import matplotlib.pyplot as plt
from importlib import reload

# zoomies
import dask.dataframe as dd
from dask.multiprocessing import get
from multiprocessing import cpu_count

# custom data loading functions
import load_data
import clean_data
import custom_feature_extraction
import custom_keras_metrics

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from imblearn.over_sampling import SMOTE

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import roc_auc_score

from tensorflow.metrics import auc as tf_auc
from tensorflow import local_variables_initializer
import keras
import keras.backend as K
from keras.preprocessing import text, sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Conv1D, \
        MaxPooling1D, LSTM, Flatten, BatchNormalization,Embedding

# %%
# dirty spaCy error workaround:
get_ipython().config.get('IPKernelApp', {})['parent_appname'] = ""

# %%
annotations ='../data/data_turk/Annotations04-09-19.json'

# %%
# reload(load_data)
df = load_data.getJSONData(annotations)
df.head()
# Out:
#                   annotation fileID  \
# 0  NON_permission_statement.      1
# 1       permission_statement      1
# 2  NON_permission_statement.      1
# 3  NON_permission_statement.      1
# 4  NON_permission_statement.      1
#
#                                                 text
# 0  a copy of this entire consent form will be giv...
# 1  i give my permission for photographs/audio/vid...
# 2  language for required recordings: the research...
# 3  "(if applicable, add) information about indivi...
# 4  this consent form will be filed securely in an...

# %% [markdown]
# ### Convert Class Labels

# %%
to  = 'label'
field = 'annotation'
    
df[to] = df.apply(lambda row:clean_data.convertAnnotationtoBinary(row, field), axis =1)

# %%
# quick summary of the data 
print('positive class:', df['label'].sum())
print('total: ', len(df))
print('total unique: ', len(set(df['text'])))
print('ratio: ', df['label'].sum()/len(df))
# Out:
# positive class: 873
# total:  3923
# total unique:  3652
# ratio:  0.2225337751720622

# %%
maxSeen = 0
for idx, row in df.iterrows():
    if len(row['text']) > maxSeen:
        maxSeen = len(row['text'])
    
print(maxSeen)
# Out:
# 1961

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ### Simple Count Features

# %%
# reload(custom_feature_extraction)
# Out:
# <module 'custom_feature_extraction' from '/Users/milk/Desktop/git/permission_statement_extraction/notebooks/custom_feature_extraction.py'>

# %%
df = custom_feature_extraction.getSimpleCounts(df)
df.head()
# Out:
#                   annotation fileID  \
# 0  NON_permission_statement.      1
# 1       permission_statement      1
# 2  NON_permission_statement.      1
# 3  NON_permission_statement.      1
# 4  NON_permission_statement.      1
#
#                                                 text  label  char_count  \
# 0  a copy of this entire consent form will be giv...      0          55
# 1  i give my permission for photographs/audio/vid...      1         124
# 2  language for required recordings: the research...      0         142
# 3  "(if applicable, add) information about indivi...      0         144
# 4  this consent form will be filed securely in an...      0          61
#
#    word_count  word_density  punctuation_count
# 0          12      4.230769                  1
# 1          19      6.200000                  3
# 2          20      6.761905                  4
# 3          23      6.000000                  7
# 4          11      5.083333                  1

# %%
nCores = cpu_count()
print(nCores) # just 4 for my machine
# Out:
# 4

# %% [markdown]
# ### Convert Raw Text to spaCy for more feature extraction

# %%
convertFrom = 'text'
convertTo = 'textDOC'

df[convertTo] = dd.from_pandas(df,npartitions=nCores).\
   map_partitions(
      lambda df : df.apply(
         lambda x :clean_data.getDocObjects(x, convertFrom),axis=1)).\
   compute(scheduler='threads')

df.head()
# Out:
#                   annotation fileID  \
# 0  NON_permission_statement.      1
# 1       permission_statement      1
# 2  NON_permission_statement.      1
# 3  NON_permission_statement.      1
# 4  NON_permission_statement.      1
#
#                                                 text  label  char_count  \
# 0  a copy of this entire consent form will be giv...      0          55
# 1  i give my permission for photographs/audio/vid...      1         124
# 2  language for required recordings: the research...      0         142
# 3  "(if applicable, add) information about indivi...      0         144
# 4  this consent form will be filed securely in an...      0          61
#
#    word_count  word_density  punctuation_count  \
# 0          12      4.230769                  1
# 1          19      6.200000                  3
# 2          20      6.761905                  4
# 3          23      6.000000                  7
# 4          11      5.083333                  1
#
#                                              textDOC
# 0  (a, copy, of, this, entire, consent, form, wil...
# 1  (i, give, my, permission, for, photographs, /,...
# 2  (language, for, required, recordings, :, the, ...
# 3  (", (, if, applicable, ,, add, ), information,...
# 4  (this, consent, form, will, be, filed, securel...

# %% [markdown]
# ### POS Counts
# _"The English part-of-speech tagger uses the OntoNotes 5 version of the Penn Treebank tag set. We also map the tags to the simpler Google Universal POS tag set."_

# %%
TAG_MAP = {'PUNCT':1,
           'SYM':2,
           'X':3,
           'CCONJ':4,
           'NUM':5,
           'DET':6,
           'PRON':7,
           'ADP':8,
           'ADJ':9,
           'AUX':10,
           'NOUN':11,
           'PROPN':12,
           'PART':13,
           'ADV':14,
           'SPACE':15,
           'INTJ':16,
           'VERB':17}

# %%
def getPOSSeq(row):
    """ get POS counts from textDOC """
    
    TAG_SEQ = []
    for token in row['textDOC'].doc:
        TAG_SEQ.append(TAG_MAP[token.pos_])
        
    return TAG_SEQ
    
df['POS_Seq'] = df.apply(lambda row: getPOSSeq(row), axis=1)

# %%
maxTokens = 0
for idx, row in df.iterrows():
    if len(row['POS_Seq']) > maxTokens:
        maxTokens = len(row['POS_Seq'])
    
print(maxTokens)
# Out:
# 348

# %%
reload(custom_feature_extraction)
# Out:
# <module 'custom_feature_extraction' from '/Users/milk/Desktop/git/permission_statement_extraction/notebooks/custom_feature_extraction.py'>

# %%
df = custom_feature_extraction.convertPOSSeqtoOneHot(df, maxTokens)
df.head()
# Out:
#                   annotation fileID  \
# 0  NON_permission_statement.      1
# 1       permission_statement      1
# 2  NON_permission_statement.      1
# 3  NON_permission_statement.      1
# 4  NON_permission_statement.      1
#
#                                                 text  label  char_count  \
# 0  a copy of this entire consent form will be giv...      0          55
# 1  i give my permission for photographs/audio/vid...      1         124
# 2  language for required recordings: the research...      0         142
# 3  "(if applicable, add) information about indivi...      0         144
# 4  this consent form will be filed securely in an...      0          61
#
#    word_count  word_density  punctuation_count  \
# 0          12      4.230769                  1
# 1          19      6.200000                  3
# 2          20      6.761905                  4
# 3          23      6.000000                  7
# 4          11      5.083333                  1
#
#                                              textDOC  \
# 0  (a, copy, of, this, entire, consent, form, wil...
# 1  (i, give, my, permission, for, photographs, /,...
# 2  (language, for, required, recordings, :, the, ...
# 3  (", (, if, applicable, ,, add, ), information,...
# 4  (this, consent, form, will, be, filed, securel...
#
#                                              POS_Seq  ...  POS_seq_posi338  \
# 0      [6, 11, 8, 6, 9, 11, 11, 17, 17, 17, 8, 7, 1]  ...              NaN
# 1  [7, 17, 9, 11, 8, 11, 2, 11, 2, 11, 11, 13, 17...  ...              NaN
# 2  [11, 8, 17, 11, 1, 6, 11, 17, 17, 11, 2, 17, 6...  ...              NaN
# 3  [1, 1, 8, 9, 1, 17, 1, 11, 8, 11, 4, 11, 9, 17...  ...              NaN
# 4        [6, 11, 11, 17, 17, 17, 14, 8, 6, 9, 11, 1]  ...              NaN
#
#    POS_seq_posi339  POS_seq_posi340  POS_seq_posi341  POS_seq_posi342  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    POS_seq_posi343  POS_seq_posi344  POS_seq_posi345  POS_seq_posi346  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    POS_seq_posi347
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 358 columns]

# %% [markdown]
# ### Sentence Vectors
# https://spacy.io/usage/vectors-similarity
#
# [1] Models for the spaCy Natural Language Processing (NLP) library: explosion/spacy-models. Explosion, 2019.
#
# _"English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl. Assigns word vectors, context-specific token vectors, POS tags, dependency parse and named entities."_

# %%
# reload(custom_feature_extraction)

df['sent_vec'] = df.apply(lambda row: custom_feature_extraction.getSentenceVectors(row), axis=1)

df.head()
# Out:
#                   annotation fileID  \
# 0  NON_permission_statement.      1
# 1       permission_statement      1
# 2  NON_permission_statement.      1
# 3  NON_permission_statement.      1
# 4  NON_permission_statement.      1
#
#                                                 text  label  char_count  \
# 0  a copy of this entire consent form will be giv...      0          55
# 1  i give my permission for photographs/audio/vid...      1         124
# 2  language for required recordings: the research...      0         142
# 3  "(if applicable, add) information about indivi...      0         144
# 4  this consent form will be filed securely in an...      0          61
#
#    word_count  word_density  punctuation_count  \
# 0          12      4.230769                  1
# 1          19      6.200000                  3
# 2          20      6.761905                  4
# 3          23      6.000000                  7
# 4          11      5.083333                  1
#
#                                              textDOC  \
# 0  (a, copy, of, this, entire, consent, form, wil...
# 1  (i, give, my, permission, for, photographs, /,...
# 2  (language, for, required, recordings, :, the, ...
# 3  (", (, if, applicable, ,, add, ), information,...
# 4  (this, consent, form, will, be, filed, securel...
#
#                                              POS_Seq  ...  POS_seq_posi339  \
# 0      [6, 11, 8, 6, 9, 11, 11, 17, 17, 17, 8, 7, 1]  ...              NaN
# 1  [7, 17, 9, 11, 8, 11, 2, 11, 2, 11, 11, 13, 17...  ...              NaN
# 2  [11, 8, 17, 11, 1, 6, 11, 17, 17, 11, 2, 17, 6...  ...              NaN
# 3  [1, 1, 8, 9, 1, 17, 1, 11, 8, 11, 4, 11, 9, 17...  ...              NaN
# 4        [6, 11, 11, 17, 17, 17, 14, 8, 6, 9, 11, 1]  ...              NaN
#
#    POS_seq_posi340  POS_seq_posi341  POS_seq_posi342  POS_seq_posi343  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    POS_seq_posi344  POS_seq_posi345  POS_seq_posi346  POS_seq_posi347  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#                                             sent_vec
# 0  [-0.02983777, 0.017629538, -0.19090748, 0.1045...
# 1  [-0.029749835, 0.12945084, -0.16006051, 0.0601...
# 2  [0.01512773, 0.047916632, -0.12940559, 0.04827...
# 3  [-0.064744644, 0.179507, -0.275384, -0.0227434...
# 4  [0.0638755, -0.007266668, -0.09555017, 0.10957...
#
# [5 rows x 359 columns]

# %% [markdown]
# ### Back up
# Save a copy so that I can get back to it if I need to... (development hack)

# %%
# point in time recovery
backup = df

# %%
# # # run this cell in an emergency
# df = backup
# df.head()

# %% [markdown]
# ### Noun_Chunks
#
# I think thiz may be biased, so I'm experimnenting leaving them out for now.

# %%
# df['noun_chunks'] = df.apply(lambda row: custom_feature_extraction.getNounChunks(row), axis=1)
# df.head()

# %%
# reload(custom_feature_extraction)

# %% [markdown]
# ### Convert chunks to one hot

# %%
# df = custom_feature_extraction.convertNounChunkstoOneHot(df)
# df.head()

# %% [markdown]
# ### Convert embeddings to one hot

# %%
df = custom_feature_extraction.convertVectoOneHot(df)
df.head()
# Out:
#                   annotation fileID  \
# 0  NON_permission_statement.      1
# 1       permission_statement      1
# 2  NON_permission_statement.      1
# 3  NON_permission_statement.      1
# 4  NON_permission_statement.      1
#
#                                                 text  label  char_count  \
# 0  a copy of this entire consent form will be giv...      0          55
# 1  i give my permission for photographs/audio/vid...      1         124
# 2  language for required recordings: the research...      0         142
# 3  "(if applicable, add) information about indivi...      0         144
# 4  this consent form will be filed securely in an...      0          61
#
#    word_count  word_density  punctuation_count  \
# 0          12      4.230769                  1
# 1          19      6.200000                  3
# 2          20      6.761905                  4
# 3          23      6.000000                  7
# 4          11      5.083333                  1
#
#                                              textDOC  \
# 0  (a, copy, of, this, entire, consent, form, wil...
# 1  (i, give, my, permission, for, photographs, /,...
# 2  (language, for, required, recordings, :, the, ...
# 3  (", (, if, applicable, ,, add, ), information,...
# 4  (this, consent, form, will, be, filed, securel...
#
#                                              POS_Seq  ...  vec_posi290  \
# 0      [6, 11, 8, 6, 9, 11, 11, 17, 17, 17, 8, 7, 1]  ...    -0.188510
# 1  [7, 17, 9, 11, 8, 11, 2, 11, 2, 11, 11, 13, 17...  ...    -0.236962
# 2  [11, 8, 17, 11, 1, 6, 11, 17, 17, 11, 2, 17, 6...  ...    -0.271302
# 3  [1, 1, 8, 9, 1, 17, 1, 11, 8, 11, 4, 11, 9, 17...  ...    -0.268256
# 4        [6, 11, 11, 17, 17, 17, 14, 8, 6, 9, 11, 1]  ...    -0.166543
#
#    vec_posi291  vec_posi292  vec_posi293  vec_posi294  vec_posi295  \
# 0     0.099692     0.020420    -0.105718     0.083448     0.008464
# 1     0.049824     0.063998    -0.000753     0.165136    -0.012342
# 2     0.049614    -0.029253    -0.012151     0.060313     0.046669
# 3     0.110001    -0.037784    -0.066260     0.008676    -0.105688
# 4     0.088511     0.055470    -0.265956     0.026951    -0.099905
#
#    vec_posi296  vec_posi297  vec_posi298  vec_posi299
# 0    -0.098004    -0.050900     0.005756     0.090207
# 1     0.015370     0.058096    -0.013941     0.123927
# 2    -0.020118    -0.032329    -0.010357     0.049174
# 3    -0.123062    -0.156906     0.128169     0.060226
# 4     0.018878    -0.014592     0.047887     0.186848
#
# [5 rows x 659 columns]

# %% [markdown]
# ### Drop Columns

# %%
columns_to_drop = [
    'text',
    'annotation',
    'sent_vec',
    'textDOC',
    'POS_Seq',
]

# %%
df = df.drop(columns_to_drop, axis=1)
df.head()
# Out:
#   fileID  label  char_count  word_count  word_density  punctuation_count  \
# 0      1      0          55          12      4.230769                  1
# 1      1      1         124          19      6.200000                  3
# 2      1      0         142          20      6.761905                  4
# 3      1      0         144          23      6.000000                  7
# 4      1      0          61          11      5.083333                  1
#
#    POS_seq_posi0  POS_seq_posi1  POS_seq_posi2  POS_seq_posi3  ...  \
# 0              6             11            8.0            6.0  ...
# 1              7             17            9.0           11.0  ...
# 2             11              8           17.0           11.0  ...
# 3              1              1            8.0            9.0  ...
# 4              6             11           11.0           17.0  ...
#
#    vec_posi290  vec_posi291  vec_posi292  vec_posi293  vec_posi294  \
# 0    -0.188510     0.099692     0.020420    -0.105718     0.083448
# 1    -0.236962     0.049824     0.063998    -0.000753     0.165136
# 2    -0.271302     0.049614    -0.029253    -0.012151     0.060313
# 3    -0.268256     0.110001    -0.037784    -0.066260     0.008676
# 4    -0.166543     0.088511     0.055470    -0.265956     0.026951
#
#    vec_posi295  vec_posi296  vec_posi297  vec_posi298  vec_posi299
# 0     0.008464    -0.098004    -0.050900     0.005756     0.090207
# 1    -0.012342     0.015370     0.058096    -0.013941     0.123927
# 2     0.046669    -0.020118    -0.032329    -0.010357     0.049174
# 3    -0.105688    -0.123062    -0.156906     0.128169     0.060226
# 4    -0.099905     0.018878    -0.014592     0.047887     0.186848
#
# [5 rows x 654 columns]

# %% [markdown]
# ### Fill NaNs

# %%
df = df.fillna(0)
df.head()
# Out:
#   fileID  label  char_count  word_count  word_density  punctuation_count  \
# 0      1      0          55          12      4.230769                  1
# 1      1      1         124          19      6.200000                  3
# 2      1      0         142          20      6.761905                  4
# 3      1      0         144          23      6.000000                  7
# 4      1      0          61          11      5.083333                  1
#
#    POS_seq_posi0  POS_seq_posi1  POS_seq_posi2  POS_seq_posi3  ...  \
# 0              6             11            8.0            6.0  ...
# 1              7             17            9.0           11.0  ...
# 2             11              8           17.0           11.0  ...
# 3              1              1            8.0            9.0  ...
# 4              6             11           11.0           17.0  ...
#
#    vec_posi290  vec_posi291  vec_posi292  vec_posi293  vec_posi294  \
# 0    -0.188510     0.099692     0.020420    -0.105718     0.083448
# 1    -0.236962     0.049824     0.063998    -0.000753     0.165136
# 2    -0.271302     0.049614    -0.029253    -0.012151     0.060313
# 3    -0.268256     0.110001    -0.037784    -0.066260     0.008676
# 4    -0.166543     0.088511     0.055470    -0.265956     0.026951
#
#    vec_posi295  vec_posi296  vec_posi297  vec_posi298  vec_posi299
# 0     0.008464    -0.098004    -0.050900     0.005756     0.090207
# 1    -0.012342     0.015370     0.058096    -0.013941     0.123927
# 2     0.046669    -0.020118    -0.032329    -0.010357     0.049174
# 3    -0.105688    -0.123062    -0.156906     0.128169     0.060226
# 4    -0.099905     0.018878    -0.014592     0.047887     0.186848
#
# [5 rows x 654 columns]

# %%
# [print(x) for x in df.columns]

# %%
df.head()
# Out:
#   fileID  label  char_count  word_count  word_density  punctuation_count  \
# 0      1      0          55          12      4.230769                  1
# 1      1      1         124          19      6.200000                  3
# 2      1      0         142          20      6.761905                  4
# 3      1      0         144          23      6.000000                  7
# 4      1      0          61          11      5.083333                  1
#
#    POS_seq_posi0  POS_seq_posi1  POS_seq_posi2  POS_seq_posi3  ...  \
# 0              6             11            8.0            6.0  ...
# 1              7             17            9.0           11.0  ...
# 2             11              8           17.0           11.0  ...
# 3              1              1            8.0            9.0  ...
# 4              6             11           11.0           17.0  ...
#
#    vec_posi290  vec_posi291  vec_posi292  vec_posi293  vec_posi294  \
# 0    -0.188510     0.099692     0.020420    -0.105718     0.083448
# 1    -0.236962     0.049824     0.063998    -0.000753     0.165136
# 2    -0.271302     0.049614    -0.029253    -0.012151     0.060313
# 3    -0.268256     0.110001    -0.037784    -0.066260     0.008676
# 4    -0.166543     0.088511     0.055470    -0.265956     0.026951
#
#    vec_posi295  vec_posi296  vec_posi297  vec_posi298  vec_posi299
# 0     0.008464    -0.098004    -0.050900     0.005756     0.090207
# 1    -0.012342     0.015370     0.058096    -0.013941     0.123927
# 2     0.046669    -0.020118    -0.032329    -0.010357     0.049174
# 3    -0.105688    -0.123062    -0.156906     0.128169     0.060226
# 4    -0.099905     0.018878    -0.014592     0.047887     0.186848
#
# [5 rows x 654 columns]

# %% [markdown]
# ### Training Data Split

# %%
train, test = train_test_split(df,stratify=df['label'],test_size=0.3, random_state=1729)

# %%
y_train = train['label']
y_test = test['label']

X_train = train.drop(['label', 'fileID'], axis=1)
X_test = test.drop(['label', 'fileID'], axis=1)

# %%
sum(y_train)
# Out:
# 611

# %% [markdown]
# ### SMOTE
# Citation:
# [1] N. V. Chawla, K. W. Bowyer, L. O. Hall, and W. P. Kegelmeyer, “SMOTE: Synthetic Minority Over-sampling Technique,” 1, vol. 16, pp. 321–357, Jun. 2002.
#
# _"method of over-sampling the minority (abnormal) class and under-sampling the majority (normal) class can achieve better classifier performance (in ROC space) than only under-sampling the majority class. This paper also shows that a combination of our method of over-sampling the minority class and under-sampling the majority class can achieve better classifier performance (in ROC space) than varying the loss ratios in Ripper or class priors in Naive Bayes. Our method of over-sampling the minority class involves creating synthetic minority class examples."_

# %%
sm = SMOTE(random_state=1729, ratio = 1.0)
X_train, y_train = sm.fit_sample(X_train, y_train)

# %%
sum(y_train)
# Out:
# 2135

# %% [markdown]
# ## Baseline Classifiers

# %%
models = []

models.append(("KNeighbors",
               KNeighborsClassifier(weights='distance')))

models.append(("LogisticRegression",
               LogisticRegression(solver='liblinear',
                                  max_iter=1000000,
                                  class_weight={1:.21},
                                  penalty='l1')))

dtBase = DecisionTreeClassifier(max_depth=10, 
                               max_features=9,
                               class_weight={1:.2})

models.append(("DecisionTree",dtBase))

rdfBase = RandomForestClassifier(n_estimators=1000,
                                class_weight={1:.2})

models.append(("RandomForest",rdfBase))


rf2 = RandomForestClassifier(n_estimators=1000, 
                             criterion='gini',
                             max_depth=10,
                             class_weight={1:.2})

models.append(("RandomForest-2",rf2))

models.append(("BaggingClassifier",
               BaggingClassifier(DecisionTreeClassifier(max_depth=3),
                                n_estimators=100,
                                max_features=9)))

models.append(("BaggingClassifier-2",
               BaggingClassifier(dtBase,
                                n_estimators=100,
                                max_features=9)))

models.append(("AdaBoostClassifier",
               AdaBoostClassifier(DecisionTreeClassifier(max_depth=1),
                                  algorithm="SAMME",
                                  n_estimators=1000)))

models.append(("GradientBoostingClassifier",
               GradientBoostingClassifier(n_estimators=100, 
                                          max_leaf_nodes=4, 
                                          max_depth = 10)))

# %%
result_rows = []
count = 1
results_frame = pd.DataFrame()

predictionsList = []
fitted_models = []

for name, model in models:
    print('training: ', name)
    model.fit(X_train, y_train)
    
    # store models in a list, in case we want 'em again
    fitted_models.append((name, model))
    
    # get predictions
    prediction_vec = model.predict(X_test)
    
    # save predictions - useful for further ensemble methods/voters
    predictionsList.append((name, prediction_vec))
    
#     # print a classifaction report for each model
#     report = classification_report(y_test, prediction_vec)
#     print(' #### ', name, '\n', report, '\n')
    
    # store result in data frame
    results_frame.loc[count, 'Model'] = name
    results_frame.loc[count, 'Accuracy'] = accuracy_score(y_test, prediction_vec)
    results_frame.loc[count, 'Precision'] = precision_score(y_test, prediction_vec)
    results_frame.loc[count, 'AUCROC'] = roc_auc_score(y_test, prediction_vec)

    # increment data frame 
    count = count + 1
# Out:
# training:  KNeighbors
# training:  LogisticRegression
# training:  DecisionTree
# training:  RandomForest
# training:  RandomForest-2
# training:  BaggingClassifier
# training:  BaggingClassifier-2
# training:  AdaBoostClassifier
# training:  GradientBoostingClassifier

# %%
# add majority class classifier for base-line comparison
majority_class = np.zeros(len(y_test))

ac = accuracy_score(y_test, majority_class)
pr = precision_score(y_test, majority_class)
roc = roc_auc_score(y_test, majority_class)

results_frame.loc[count, 'Model'] = 'Naive Baseline - MajorityClassClassifier'
results_frame.loc[count, 'Accuracy'] = ac
results_frame.loc[count, 'Precision'] = pr
results_frame.loc[count, 'AUCROC'] = roc

count = count + 1
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
results_frame.head(len(results_frame))
# Out:
#                                        Model  Accuracy  Precision    AUCROC
# 1                                 KNeighbors  0.480034   0.260929  0.568875
# 2                         LogisticRegression  0.826678   0.723077  0.659717
# 3                               DecisionTree  0.723025   0.374016  0.594412
# 4                               RandomForest  0.840272   0.630282  0.784226
# 5                             RandomForest-2  0.836873   0.791667  0.667637
# 6                          BaggingClassifier  0.760408   0.473118  0.728774
# 7                        BaggingClassifier-2  0.779099   0.750000  0.505179
# 8                         AdaBoostClassifier  0.820731   0.584158  0.768934
# 9                 GradientBoostingClassifier  0.813934   0.572391  0.755029
# 10  Naive Baseline - MajorityClassClassifier  0.777400   0.000000  0.500000

# %% [markdown]
# ## Neural Network (to migrate to models)
# Neural Network Classifier Code (keras). No Need for it now, but may be useful in the event that BERT training time is too costly.

# %%
print(X_train.shape[1])
print(X_test.shape)
# Out:
# 652
# (1177, 652)

# %%
y_train = keras.utils.to_categorical(y_train, num_classes=2)
y_test = keras.utils.to_categorical(y_test, num_classes=2)

# %%
dim = X_train.shape[1]

# Create model
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=dim))
model.add(Dense(units=500, activation='softmax'))
# model.add(Conv1D(128, 5, activation='relu'))
model.add(Dense(units=10, activation='softmax'))
model.add(Dense(units=1000, activation='relu'))
model.add(Dense(units=500, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

model.compile(loss='categorical_crossentropy',
#               optimizer='adam',
              optimizer=keras.optimizers.Adagrad(lr=0.001), 
              metrics=['accuracy', 
                       custom_keras_metrics.keras_precision, 
                       custom_keras_metrics.keras_recall, 
                       custom_keras_metrics.keras_auc])

# Train
mod = model.fit(X_train, y_train, validation_data=(X_test,y_test), 
          epochs=100, batch_size=3, shuffle=True)
# Out:
# Train on 4270 samples, validate on 1177 samples
# Epoch 1/100
# 4270/4270 [==============================] - 9s 2ms/step - loss: 0.6937 - acc: 0.4963 - keras_precision: 0.4963 - keras_recall: 0.4963 - keras_auc: 0.4945 - val_loss: 0.6898 - val_acc: 0.7774 - val_keras_precision: 0.7774 - val_keras_recall: 0.7774 - val_keras_auc: 0.5234
# Epoch 2/100
# 4270/4270 [==============================] - 8s 2ms/step - loss: 0.6929 - acc: 0.5131 - keras_precision: 0.5131 - keras_recall: 0.5131 - keras_auc: 0.5409 - val_loss: 0.6931 - val_acc: 0.4843 - val_keras_precision: 0.4843 - val_keras_recall: 0.4843 - val_keras_auc: 0.5345
# Epoch 3/100
# 4270/4270 [==============================] - 8s 2ms/step - loss: 0
100
# 4270/4270 [==============================] - 8s 2ms/step - loss: 0.2820 - acc: 0.8897 - keras_precision: 0.8897 - keras_recall: 0.8897 - keras_auc: 0.8784 - val_loss: 0.5231 - val_acc: 0.7876 - val_keras_precision: 0.7876 - val_keras_recall: 0.7876 - val_keras_auc: 0.8788
# Epoch 97/100
# 4270/4270 [==============================] - 7s 2ms/step - loss: 0.2813 - acc: 0.8911 - keras_precision: 0.8911 - keras_recall: 0.8911 - keras_auc: 0.8791 - val_loss: 0.5278 - val_acc: 0.7859 - val_keras_precision: 0.7859 - val_keras_recall: 0.7859 - val_keras_auc: 0.8794
# Epoch 98/100
# 4270/4270 [==============================] - 8s 2ms/step - loss: 0.2800 - acc: 0.8895 - keras_precision: 0.8895 - keras_recall: 0.8895 - keras_auc: 0.8797 - val_loss: 0.5471 - val_acc: 0.7782 - val_keras_precision: 0.7782 - val_keras_recall: 0.7782 - val_keras_auc: 0.8800
# Epoch 99/100
# 4270/4270 [==============================] - 8s 2ms/step - loss: 0.2785 - acc: 0.8911 - keras_precision: 0.8911 - keras_recall: 0.8911 - keras_auc: 0.8803 - val_loss: 0.5116 - val_acc: 0.7935 - val_keras_precision: 0.7935 - val_keras_recall: 0.7935 - val_keras_auc: 0.8807
# Epoch 100/100
# 4270/4270 [==============================] - 8s 2ms/step - loss: 0.2780 - acc: 0.8920 - keras_precision: 0.8920 - keras_recall: 0.8920 - keras_auc: 0.8810 - val_loss: 0.5211 - val_acc: 0.7901 - val_keras_precision: 0.7901 - val_keras_recall: 0.7901 - val_keras_auc: 0.8813

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_65 (Dense)             (None, 100)               65300
# _________________________________________________________________
# dense_66 (Dense)             (None, 500)               50500
# _________________________________________________________________
# dense_67 (Dense)             (None, 10)                5010
# _________________________________________________________________
# dense_68 (Dense)             (None, 1000)              11000
# _________________________________________________________________
# dense_69 (Dense)             (None, 500)               500500
# _________________________________________________________________
# dense_70 (Dense)             (None, 2)                 1002
# =================================================================
# Total params: 633,312
# Trainable params: 633,312
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# %matplotlib inline
plt.plot(mod.history['keras_precision'])
plt.plot(mod.history['val_keras_precision'])
plt.title('model keras_precision')
plt.ylabel('precision')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(mod.history['loss'])
plt.plot(mod.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
results_frame.loc[count, 'Model'] = 'Simple ANN'
results_frame.loc[count, 'Accuracy'] = mod.history['acc'][-1]
results_frame.loc[count, 'Precision'] = mod.history['keras_precision'][-1]
results_frame.loc[count, 'AUCROC'] = mod.history['val_keras_auc'][-1]

results_frame.head(len(results_frame))
# Out:
#                                        Model  Accuracy  Precision    AUCROC
# 1                                 KNeighbors  0.480034   0.260929  0.568875
# 2                         LogisticRegression  0.826678   0.723077  0.659717
# 3                               DecisionTree  0.723025   0.374016  0.594412
# 4                               RandomForest  0.840272   0.630282  0.784226
# 5                             RandomForest-2  0.836873   0.791667  0.667637
# 6                          BaggingClassifier  0.760408   0.473118  0.728774
# 7                        BaggingClassifier-2  0.779099   0.750000  0.505179
# 8                         AdaBoostClassifier  0.820731   0.584158  0.768934
# 9                 GradientBoostingClassifier  0.813934   0.572391  0.755029
# 10  Naive Baseline - MajorityClassClassifier  0.777400   0.000000  0.500000
# 11                                Simple ANN  0.892037   0.892037  0.881316

# %% [markdown]
# ### save the model

# %%
# serialize model to YAML
model_yaml = model.to_yaml()
with open("../models/model.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# serialize weights to HDF5
model.save_weights("../models/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
